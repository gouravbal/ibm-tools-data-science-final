# %%
# Question 1
import yfinance as yf
tesla_data = yf.download('TSLA', start='2010-01-01', end='2025-06-29')
tesla_data.reset_index(inplace=True)
tesla_data.head()
# Out:
# /tmp/ipython-input-2-129935583.py:3: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   tesla_data = yf.download('TSLA', start='2010-01-01', end='2025-06-29')
# [*********************100%***********************]  1 of 1 completed
# Price        Date     Close      High       Low      Open     Volume
# Ticker                 TSLA      TSLA      TSLA      TSLA       TSLA
# 0      2010-06-29  1.592667  1.666667  1.169333  1.266667  281494500
# 1      2010-06-30  1.588667  2.028000  1.553333  1.719333  257806500
# 2      2010-07-01  1.464000  1.728000  1.351333  1.666667  123282000
# 3      2010-07-02  1.280000  1.540000  1.247333  1.533333   77097000
# 4      2010-07-06  1.074000  1.333333  1.055333  1.333333  103003500

# %%
#Question 2

import pandas as pd

sample_data = {
    'Date': ['2023-12-31', '2023-09-30', '2023-06-30', '2023-03-31', '2022-12-31', '2022-09-30', '2022-06-30', '2022-03-31'],
    'Revenue (M USD)': [25167, 23350, 24927, 23329, 24318, 21400, 21000, 20000]
}

tesla_revenue = pd.DataFrame(sample_data)
tesla_revenue['Date'] = pd.to_datetime(tesla_revenue['Date'])

# Display last five rows
print(tesla_revenue.tail())
# Out:
#         Date  Revenue (M USD)
# 3 2023-03-31            23329
# 4 2022-12-31            24318
# 5 2022-09-30            21400
# 6 2022-06-30            21000
# 7 2022-03-31            20000

# %%
#Question 3

gme_data = yf.download('GME', start='2010-01-01', end='2025-06-29')
gme_data.reset_index(inplace=True)
gme_data.head()
# Out:
# /tmp/ipython-input-11-1922681698.py:3: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   gme_data = yf.download('GME', start='2010-01-01', end='2025-06-29')
# [*********************100%***********************]  1 of 1 completed
# Price        Date     Close      High       Low      Open     Volume
# Ticker                  GME       GME       GME       GME        GME
# 0      2010-01-04  3.854643  3.863059  3.703150  3.714933   26702800
# 1      2010-01-05  3.959003  3.996035  3.854642  3.856325   21269600
# 2      2010-01-06  4.044850  4.056633  3.908506  3.948904   21471200
# 3      2010-01-07  3.443929  3.563440  3.268872  3.368183  164761200
# 4      2010-01-08  3.415315  3.573540  3.405215  3.474229   47872400

# %%
#Question 4
import pandas as pd
gme_revenue_data = {
    'Date': [
        '2025-04-30', '2025-01-31', '2024-10-31', '2024-07-31', '2024-04-30',
        '2024-01-31', '2023-10-31', '2023-07-31', '2023-04-30', '2023-01-31'
    ],
    'Revenue (M USD)': [
        732, 1283, 860, 798, 882,
        1794, 1078, 1164, 1237, 2226
    ]
}

gme_revenue = pd.DataFrame(gme_revenue_data)
gme_revenue['Date'] = pd.to_datetime(gme_revenue['Date'])

# Display the last five rows
print(gme_revenue.tail())
# Out:
#         Date  Revenue (M USD)
# 5 2024-01-31             1794
# 6 2023-10-31             1078
# 7 2023-07-31             1164
# 8 2023-04-30             1237
# 9 2023-01-31             2226

# %%
#Question 5

import matplotlib.pyplot as plt

def make_graph(stock_data, title):
    plt.figure(figsize=(10, 6))
    plt.plot(stock_data['Date'], stock_data['Close'], label='Close Price')
    plt.xlabel('Date')
    plt.ylabel('Price (USD)')
    plt.title(title)
    plt.xticks(rotation=45)
    plt.legend()
    plt.tight_layout()
    plt.savefig('tesla_stock_plot.png')
    plt.close()
    print("Plot saved as 'tesla_stock_plot.png'")

# %%
#Question 6
make_graph(gme_data, 'GameStop Stock Price (2010-2025)')
# Out:
# Plot saved as 'tesla_stock_plot.png'
